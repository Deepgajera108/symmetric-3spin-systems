# %%
import numpy as np
import pandas as pd
import scipy.optimize  # Import scipy for optimization
'''
# Load the CSV file
file_path = 'D:\Desktop\Random Research\coding\hamiltonian_results_j2_j3.csv'
data = pd.read_csv(file_path, header=0, skipinitialspace=True)

# Strip whitespace from column headers
data.columns = data.columns.str.strip()

# Iterate through each row of the file
for index, row in data.iterrows():
    # Extract values from the row
    j1 = row['j1']
    j4 = row['j4']
    j2 = row['j2']
    j3 = row['j3']
    
    # Perform calculations
    e3 = -(j1 + j2 + j3) / 4 + np.sqrt(3) * j4 / 2
    e4 = -(j1 + j2 + j3) / 4 - np.sqrt(3) * j4 / 2
    ematrix = np.array([[3 * j1 / 4, np.sqrt(3) * (j2 - j3) / 4],
                        [np.sqrt(3) * (j2 - j3) / 4, -j1 / 4 + j2 / 2 + j3 / 2]])
    evals = np.linalg.eig(ematrix)
    #energy = np.array([evals[0][0], evals[0][1], e3, e4])
    alpha = evals[1][0][0]
    beta = evals[1][0][1]
    c1 = np.sqrt(2 / 3) * np.abs(beta) * np.sqrt(1 - (beta**2) / 3)
    c2 = np.sqrt(2 / 3) * np.abs(alpha) * np.sqrt(1 - (alpha**2) / 3)
    concurs = np.array([c1, c2, 2 / 3, 2 / 3, 0])
    energy = np.array([row['Eigenvalue1'], row['Eigenvalue2'], row['e3'], row['e4']])
    alpha = row['First Eigenvector Comp 1']
    print(concurs)

    #print (j1,j2,j3,j4)
    print(f"  Energy: {energy}")
    
    # Print or store results
    print(f"Row {index}:")
    print(f"  Evals: {evals}")
    print(f"  E3: {e3}, E4: {e4}")
    print(f"  Concurrences: {concurs}")
    print("-" * 40)
    '''
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# <>:4: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\deepg\AppData\Local\Temp\ipykernel_6676\3108678579.py:4: SyntaxWarning: invalid escape sequence '\D'
#   '''
# '\n# Load the CSV file\nfile_path = \'D:\\Desktop\\Random Research\\coding\\hamiltonian_results_j2_j3.csv\'\ndata = pd.read_csv(file_path, header=0, skipinitialspace=True)\n\n# Strip whitespace from column headers\ndata.columns = data.columns.str.strip()\n\n# Iterate through each row of the file\nfor index, row in data.iterrows():\n    # Extract values from the row\n    j1 = row[\'j1\']\n    j4 = row[\'j4\']\n    j2 = row[\'j2\']\n    j3 = row[\'j3\']\n    \n    # Perform calculations\n    e3 = -(j1 + j2 + j3) / 4 + np.sqrt(3) * j4 / 2\n    e4 = -(j1 + j2 + j3) / 4 - np.sqrt(3) * j4 / 2\n    ematrix = np.array([[3 * j1 / 4, np.sqrt(3) * (j2 - j3) / 4],\n                        [np.sqrt(3) * (j2 - j3) / 4, -j1 / 4 + j2 / 2 + j3 / 2]])\n    evals = np.linalg.eig(ematrix)\n    #energy = np.array([evals[0][0], evals[0][1], e3, e4])\n    alpha = evals[1][0][0]\n    beta = evals[1][0][1]\n    c1 = np.sqrt(2 / 3) * np.abs(beta) * np.sqrt(1 - (beta**2) / 3)\n    c2 = np.sqrt(2 / 3) * np.abs(alpha) * np.sqrt(1 - (alpha**2) / 3)\n    concurs = np.array([c1, c2, 2 / 3, 2 / 3, 0])\n    energy = np.array([row[\'Eigenvalue1\'], row[\'Eigenvalue2\'], row[\'e3\'], row[\'e4\']])\n    alpha = row[\'First Eigenvector Comp 1\']\n    print(concurs)\n\n    #print (j1,j2,j3,j4)\n    print(f"  Energy: {energy}")\n    \n    # Print or store results\n    print(f"Row {index}:")\n    print(f"  Evals: {evals}")\n    print(f"  E3: {e3}, E4: {e4}")\n    print(f"  Concurrences: {concurs}")\n    print("-" * 40)\n    '

# %%
def concurance(unent_arry,vecs,energy,concurs):
    det = np.linalg.det(vecs)
    #print("det=", det)
    invstrans=np.linalg.pinv(np.transpose(vecs))

    unent_arry_inv = np.zeros((7,5), dtype = float)
    c_array = np.zeros((7), dtype = float)
    for count in range(0,7):
        unent_arry_inv[count] = np.matmul(invstrans,unent_arry[count])
        c_array[count] = (-1)*(np.dot(unent_arry_inv[count], concurs))
    #print(invstrans)
    #print(unent_arry_inv)
    #print(np.transpose(unent_arry_inv))

    temp = 0.2
    partit = np.sum(np.exp(-energy/temp))
    probs = np.exp(-energy/temp)/partit
    probs1 = np.pad(probs, (0,1))
    concur_init = np.dot(probs1,concurs)

    Au1 = np.transpose(unent_arry_inv)
    Au2 = (-1)*np.identity(7)
    Aub = np.append(Au1, Au2, axis=0)
    bub = np.pad(probs, (0,8))
    output = scipy.optimize.linprog(c_array, Aub, bub)
    concur_fin = concur_init+output.fun
    density_fin1 = probs1 
    for count in range(0,5):
        density_fin1[count] -= np.dot(output.x, Au1[count])
    density_fin2 = output.x
    density_fin = np.append(density_fin1, density_fin2)
    #print(Au1)
    #print(concur_init,probs,probs1)
    print(concur_fin, density_fin1)
    print(output)

    return concur_fin, density_fin

# %%
# Load the CSV file containing the data
input_file = "hamiltonian_results_j2_j3.csv"  # Replace with your actual filename
output_file = "updated_hamiltonian_results_j2_j3_T_02.csv"  # Output filename
data = pd.read_csv(input_file)
# Prepare columns for energy, concurs, and other inputs
#unent_arry = np.array([[0,0,0,0,1],[1/4,1/8,1/8,0,3/4],[1/4,-1/8,1/8,0,3/4],[1/4,1/24,-1/24,0,3/4], [1/4,-1/24,-1/24,0,3/4],[1/4,0,0,1/24,3/4],[1/4,0,0,-1/24,3/4]])
#vecs = np.array([[.9974,.0146,.0004,0,.0026],[.0026 ,-.0146,.1662,0,.9974], [0,0,-.0833, .1443,1], [0,0,-.0833, -.1443,1], [1,0,0,0,0]])


#concurance(unent_arry, vecs, energy, concurs)

# %%
print(data.columns.tolist())
data.columns = data.columns.str.strip()
# Out:
# ['j1', ' j4', ' j2', ' j3', ' Eigenvalue1', ' Eigenvalue2', ' e3', ' e4', ' First Eigenvector Comp 1', ' First Eigenvector Comp 2']

# %%
# Iterate through each row and calculate concur_fin
concur_fin_list = []
density_fin_list = []

unent_arry = np.array([[0,0,0,0,1],[1/4,1/8,1/8,0,3/4],[1/4,-1/8,1/8,0,3/4],[1/4,1/24,-1/24,0,3/4], [1/4,-1/24,-1/24,0,3/4],[1/4,0,0,1/24,3/4],[1/4,0,0,-1/24,3/4]])

for index, row in data.iterrows():
    alpha = row['First Eigenvector Comp 1']
    beta = row['First Eigenvector Comp 2']
    print({alpha}, {beta})
    #vecs = np.array([[alpha**2,.0146,.0004,0,.0026],[.0026 ,-.0146,.1662,0,.9974], [0,0,-.0833, .1443,1], [0,0,-.0833, -.1443,1], [1,0,0,0,0]],dtype=np.float64)

    vecs = np.array([[alpha**2,alpha*beta/(2*np.sqrt(3)),beta**2/6,0,beta**2],[beta**2 ,-alpha*beta/(2*np.sqrt(3)),alpha**2/6,0,alpha**2], [0,0,-.0833, .1443,1], [0,0,-.0833, -.1443,1], [1,0,0,0,0]])
    c1 = np.sqrt(2/3)*np.abs(beta)*np.sqrt(1 - (beta**2)/3)
    c2 = np.sqrt(2/3)*np.abs(alpha)*np.sqrt(1-(alpha**2)/3)
    concurs = np.array([c1,c2,2/3,2/3,0])
    # Extract energy and parameters from the row
    energy = np.array([row['Eigenvalue1'], row['Eigenvalue2'], row['e3'], row['e4']])
    # Compute concur_fin
    #print( energy, concurs)
    concur_fin, density_fin = concurance(unent_arry, vecs, energy, concurs)
    #print(concur_fin)
    concur_fin_list.append(concur_fin)
    # Append density_fin
    density_fin_list.append(density_fin)

# Add the concur_fin column to the DataFrame
data['concur_fin'] = concur_fin_list

# Dynamically create columns for density_fin
density_fin_array = np.array(density_fin_list)
num_density_cols = density_fin_array.shape[1]

for i in range(num_density_cols):
    col_name = f'density_fin_{i+1}'
    data[col_name] = density_fin_array[:, i]

# Save the updated DataFrame to a new CSV file
data.to_csv(output_file, index=False)

print(f"Updated data saved to {output_file}")
# Out:
# {np.float64(-0.0)} {np.float64(1.0)}
# 0.3329648879458692 [ 4.99447332e-01  4.99723611e-01  0.00000000e+00  0.00000000e+00
#  -9.07915056e-20]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.0005527049331053432
#               x: [ 8.291e-04 -0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 8.291e-04 -0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  6.667e-01
#                               6.667e-01  2.113e-01  7.887e-01]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 4.994e-01  4.997e-01  0.000e+00  0.000e+00
#                               0.000e+00  8.291e-04  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -0.000e+00 -0.000e+00 -2.000e+00
#                              -4.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.86603)} {np.float64(-0.5)}
# -1.6653345369377348e-16 [-2.22044605e-16 -5.55111512e-17 -7.03105109e-17 -1.91903785e-17
#   4.14461950e-01]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.4746279656388119
#               x: [ 0.000e+00  4.145e-01  1.697e-01  0.000e+00  0.000e+00
#                    6.880e-04  6.880e-04]
#             nit: 8
#           lower:  residual: [ 0.000e+00  4.145e-01  1.697e-01  0.000e+00
#                               0.000e+00  6.880e-04  6.880e-04]
#                  marginals: [-1.110e-16  0.000e+00  0.000e+00  0.000e+00
#                              -2.776e-16  0.000e+00  0.000e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               4.145e-01  0.000e+00  4.145e-01  1.697e-01
#                               0.000e+00  0.000e+00  6.880e-04  6.880e-04]
#                  marginals: [-3.909e-01 -6.124e-01 -6.667e-01 -6.667e-01
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.86603)} {np.float64(-0.5)}
# -1.6653345369377348e-16 [ 1.11022302e-16  5.55111512e-17 -7.53520510e-17 -4.40728183e-17
#   4.86714341e-01]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0
-03  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.785e+00 -1.724e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.86603)} {np.float64(-0.5)}
# 0.3900274320785498 [ 9.97849535e-01 -2.71050543e-20  0.00000000e+00 -2.16840434e-19
#   2.46667888e-04]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.0011725556518289192
#               x: [ 0.000e+00  2.468e-04  0.000e+00  1.657e-03  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 7
#           lower:  residual: [ 0.000e+00  2.468e-04  0.000e+00  1.657e-03
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 3.909e-01  0.000e+00  1.173e+00  0.000e+00
#                               3.909e-01  5.421e-01  4.419e-02]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.978e-01  0.000e+00  0.000e+00 -2.168e-19
#                               2.467e-04  0.000e+00  2.468e-04  0.000e+00
#                               1.657e-03  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.785e+00 -1.724e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.86603)} {np.float64(-0.5)}
# 0.390103220784376 [ 9.98043433e-01  1.35525272e-20  0.00000000e+00 -2.16840434e-19
#   1.49677434e-04]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.001086039823724192
#               x: [ 0.000e+00  1.498e-04  0.000e+00  1.657e-03  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 7
#           lower:  residual: [ 0.000e+00  1.498e-04  0.000e+00  1.657e-03
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 3.909e-01  0.000e+00  1.173e+00  0.000e+00
#                               3.909e-01  5.421e-01  4.419e-02]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.980e-01  0.000e+00  0.000e+00 -2.168e-19
#                               1.497e-04  0.000e+00  1.498e-04  0.000e+00
#                               1.657e-03  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.785e+00 -1.724e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.86603)} {np.float64(0.5)}
# -5.551115123125783e-17 [ 0.00000000e+00  0.00000000e+00 -7.04731412e-17 -1.92445886e-17
#   4.14461950e-01]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.47462796563881177
#               x: [ 0.000e+00  1.701e-01  4.145e-01  0.000e+00  1.032e-03
#                    0.000e+00 -0.000e+00]
#             nit: 7
#           lower:  residual: [ 0.000e+00  1.701e-01  4.145e-01  0.000e+00
#                               1.032e-03  0.000e+00 -0.000e+00]
#                  marginals: [-2.220e-16  0.000e+00  0.000e+00 -2.220e-16
#                               0.000e+00 -1.110e-16  0.000e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               4.145e-01  0.000e+00  1.701e-01  4.145e-01
#                               0.000e+00  1.032e-03  0.000e+00  0.000e+00]
#                  marginals: [-3.909e-01 -6.124e-01 -6.667e-01 -6.667e-01
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-1.0)} {np.float64(0.0)}
# 0.25117712591767855 [6.21909495e-01 3.76765689e-01 1.62630326e-19 0.00000000e+00
#  0.00000000e+00]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.0008832106142222843
#               x: [ 1.325e-03 -0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 1.325e-03 -0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  6.667e-01
#                               6.667e-01  2.113e-01  7.887e-01]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 6.219e-01  3.768e-01  1.626e-19  0.000e+00
#                               0.000e+00  1.325e-03  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -0.000e+00 -0.000e+00 -2.000e+00
#                              -4.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.96593)} {np.float64(-0.25882)}
# 1.1102230246251565e-16 [-1.11022302e-16  1.66533454e-16  1.40946282e-17  2.49366500e-17
#   5.67832926e-01]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.3412653021574744
#               x: [ 0.000e+00  3.326e-01  9.742e-02  0.000e+00  0.000e+00
#                    1.068e-03  1.068e-03]
#             nit: 7
#           lower:  residual: [ 0.000e+00  3.326e-01  9.742e-02  0.000e+00
#                               0.000e+00  1.068e-03  1.068e-03]
#                  marginals: [ 1.110e-16  0.000e+00  0.000e+00  0.000e+00
#                               5.551e-17  0.000e+00  0.000e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               5.678e-01  0.000e+00  3.326e-01  9.742e-02
#                               0.000e+00  0.000e+00  1.068e-03  1.068e-03]
#                  marginals: [-2.090e-01 -6.546e-01 -6.667e-01 -6.667e-01
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.937)} {np.float64(-0.34934)}
# 0.029544050255747856 [ 1.05751243e-01  2.77555756e-17 -2.67797937e-16 -2.18033057e-16
#   5.35572381e-01]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.32678614201584644
#               x: [ 0.000e+00  3.568e-01  0.000e+00  1.836e-03  0.000e+00
#                   -0.000e+00  0.000e+00]
#             nit: 5
#           lower:  residual: [ 0.000e+00  3.568e-01  0.000e+00  1.836e-03
#                               0.000e+00 -0.000e+00  0.000e+00]
#                  marginals: [ 3.140e-01  0.000e+00  9.419e-01  0.000e+00
#                               3.140e-01  0.000e+00  4.709e-01]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 1.058e-01  0.000e+00  0.000e+00  0.000e+00
#                               5.356e-01  0.000e+00  3.568e-01  0.000e+00
#                               1.836e-03  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.551e+00 -8.227e-03 -1.639e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.92016)} {np.float64(-0.39155)}
# 0.12926620832051036 [ 4.15082150e-01  0.00000000e+00 -1.16790258e-15 -1.10556096e-15
#   3.33185785e-01]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.2285767624100182
#               x: [ 0.000e+00  2.497e-01  0.000e+00  2.016e-03  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 5
#           lower:  residual: [ 0.000e+00  2.497e-01  0.000e+00  2.016e-03
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 3.308e-01  0.000e+00  9.924e-01  0.000e+00
#                               3.308e-01  7.815e-03  4.884e-01]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 4.151e-01  0.000e+00  0.000e+00  0.000e+00
#                               3.332e-01  0.000e+00  2.497e-01  0.000e+00
#                               2.016e-03  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.610e+00 -0.000e+00 -1.664e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.90958)} {np.float64(-0.41554)}
# 0.20556855523174497 [ 6.24111410e-01  0.00000000e+00 -4.17309416e-16 -4.03214788e-16
#   2.07717358e-01]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.15204840646333698
#               x: [ 0.000e+00  1.660e-01  0.000e+00  2.144e-03  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 4
#           lower:  residual: [ 0.000e+00  1.660e-01  0.000e+00  2.144e-03
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 3.417e-01  0.000e+00  1.025e+00  0.000e+00
#                               3.417e-01  1.442e-02  4.981e-01]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 6.241e-01  0.000e+00 -2.168e-19  0.000e+00
#                               2.077e-01  0.000e+00  1.660e-01  0.000e+00
#                               2.144e-03  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.645e+00 -0.000e+00 -1.675e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.90239)} {np.float64(-0.43092)}
# 0.25980992899967426 [ 7.62394125e-01  0.00000000e+00 -1.11239143e-16 -1.06793914e-16
#   1.28453094e-01]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.09820040490580094
#               x: [ 0.000e+00  1.069e-01  0.000e+00  2.232e-03  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 4
#           lower:  residual: [ 0.000e+00  1.069e-01  0.000e+00  2.232e-03
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 3.493e-01  0.000e+00  1.048e+00  0.000e+00
#                               3.493e-01  1.901e-02  5.049e-01]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 7.624e-01  0.000e+00  0.000e+00  0.000e+00
#                               1.285e-01  0.000e+00  1.069e-01  0.000e+00
#                               2.232e-03  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.668e+00 -0.000e+00 -1.683e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.89722)} {np.float64(-0.44159)}
# 0.2968293931775179 [ 8.51388211e-01  6.93889390e-18 -6.52689708e-17 -7.49183701e-17
#   7.88481642e-02]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.06237579107930992
#               x: [ 0.000e+00  6.747e-02  0.000e+00  2.290e-03  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 4
#           lower:  residual: [ 0.000e+00  6.747e-02  0.000e+00  2.290e-03
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 3.549e-01  0.000e+00  1.065e+00  0.000e+00
#                               3.549e-01  2.239e-02  5.099e-01]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 8.514e-01  0.000e+00  3.253e-19  0.000e+00
#                               7.885e-02  0.000e+00  6.747e-02  0.000e+00
#                               2.290e-03  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.685e+00 -0.000e+00 -1.688e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.89332)} {np.float64(-0.44942)}
# 0.32160247167965195 [ 9.07502234e-01  3.46944695e-18 -4.41270284e-17 -3.49113100e-17
#   4.81427849e-02]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.0393208987166321
#               x: [ 0.000e+00  4.203e-02  0.000e+00  2.327e-03  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 4
#           lower:  residual: [ 0.000e+00  4.203e-02  0.000e+00  2.327e-03
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 3.591e-01  0.000e+00  1.077e+00  0.000e+00
#                               3.591e-01  2.497e-02  5.137e-01]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.075e-01  0.000e+00  2.168e-19  0.000e+00
#                               4.814e-02  0.000e+00  4.203e-02  0.000e+00
#                               2.327e-03  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.698e+00 -0.000e+00 -1.693e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.89028)} {np.float64(-0.45541)}
# 0.3380905306356983 [ 9.42393321e-01  0.00000000e+00 -2.22261445e-17 -1.73472348e-17
#   2.92988746e-02]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.024787578232525424
#               x: [ 0.000e+00  2.596e-02  0.000e+00  2.351e-03  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 4
#           lower:  residual: [ 0.000e+00  2.596e-02  0.000e+00  2.351e-03
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 3.625e-01  0.000e+00  1.087e+00  0.000e+00
#                               3.625e-01  2.701e-02  5.167e-01]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.424e-01  0.000e+00 -2.168e-19  0.000e+00
#                               2.930e-02  0.000e+00  2.596e-02  0.000e+00
#                               2.351e-03  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.707e+00 -0.000e+00 -1.696e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.88785)} {np.float64(-0.46013)}
# 0.34911740049891904 [ 9.63893343e-01  1.73472348e-18 -9.32413868e-18 -9.97465999e-18
#   1.77994473e-02]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.015743674081789553
#               x: [ 0.000e+00  1.594e-02  0.000e+00  2.366e-03  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 4
#           lower:  residual: [ 0.000e+00  1.594e-02  0.000e+00  2.366e-03
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 3.652e-01  0.000e+00  1.096e+00  0.000e+00
#                               3.652e-01  2.866e-02  5.192e-01]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.639e-01  0.000e+00 -4.337e-19  0.000e+00
#                               1.780e-02  0.000e+00  1.594e-02  0.000e+00
#                               2.366e-03  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.715e+00 -0.000e+00 -1.699e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.88586)} {np.float64(-0.46395)}
# ...
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.767e-01  0.000e+00  7.641e-03  7.641e-03
#                               1.855e-03  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  6.184e-03  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.427e+01 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.96975)} {np.float64(0.24412)}
# 0.2057353633103574 [0.97132645 0.         0.01054512 0.01054512 0.00204919]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.003347332980822211
#               x: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  5.534e-03
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               5.534e-03  0.000e+00  0.000e+00]
#                  marginals: [ 3.568e+00  1.070e+01  7.357e+00  1.116e+00
#                               0.000e+00  2.676e+00  2.676e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.713e-01  0.000e+00  1.055e-02  1.055e-02
#                               2.049e-03  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  5.534e-03  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.289e+01 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.97669)} {np.float64(0.21466)}
# 0.18643237816256614 [0.96502203 0.         0.01394832 0.01394832 0.00222528]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.002948251860491066
#               x: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  4.856e-03
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               4.856e-03  0.000e+00  0.000e+00]
#                  marginals: [ 3.205e+00  9.615e+00  6.812e+00  9.343e-01
#                               0.000e+00  2.404e+00  2.404e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.650e-01  0.000e+00  1.395e-02  1.395e-02
#                               2.225e-03  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  4.856e-03  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.178e+01 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.98268)} {np.float64(0.18533)}
# 0.167902060159449 [0.95772951 0.         0.01785689 0.01785689 0.00238405]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.00254194284670763
#               x: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  4.173e-03
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               4.173e-03  0.000e+00  0.000e+00]
#                  marginals: [ 2.909e+00  8.727e+00  6.368e+00  7.863e-01
#                               0.000e+00  2.182e+00  2.182e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.577e-01  0.000e+00  1.786e-02  1.786e-02
#                               2.384e-03  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  4.173e-03  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.087e+01 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.9877)} {np.float64(0.15636)}
# 0.15039482166900564 [0.94944319 0.         0.0222576  0.0222576  0.00253344]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.002143585613493244
#               x: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  3.508e-03
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               3.508e-03  0.000e+00  0.000e+00]
#                  marginals: [ 2.664e+00  7.992e+00  6.000e+00  6.639e-01
#                               0.000e+00  1.998e+00  1.998e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.494e-01  0.000e+00  2.226e-02  2.226e-02
#                               2.533e-03  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  3.508e-03  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -1.012e+01 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.99178)} {np.float64(0.12797)}
# 0.13412635086020017 [0.94018587 0.         0.02711819 0.02711819 0.0026926 ]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.001767578838356036
#               x: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  2.885e-03
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               2.885e-03  0.000e+00  0.000e+00]
#                  marginals: [ 2.459e+00  7.377e+00  5.692e+00  5.615e-01
#                               0.000e+00  1.844e+00  1.844e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.402e-01  0.000e+00  2.712e-02  2.712e-02
#                               2.693e-03  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  2.885e-03  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -9.481e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.99495)} {np.float64(0.10034)}
# 0.11925565594358606 [0.9299873  0.         0.03239422 0.03239422 0.00290226]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.001425803720522008
#               x: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  2.322e-03
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               2.322e-03  0.000e+00  0.000e+00]
#                  marginals: [ 2.286e+00  6.857e+00  5.432e+00  4.750e-01
#                               0.000e+00  1.714e+00  1.714e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.300e-01  0.000e+00  3.239e-02  3.239e-02
#                               2.902e-03  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  2.322e-03  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -8.940e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.99729)} {np.float64(0.07363)}
# 0.10589471134475155 [0.91886147 0.         0.03802796 0.03802796 0.00325277]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.0011258412769894973
#               x: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  1.830e-03
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               1.830e-03  0.000e+00  0.000e+00]
#                  marginals: [ 2.138e+00  6.415e+00  5.211e+00  4.013e-01
#                               0.000e+00  1.604e+00  1.604e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.189e-01  0.000e+00  3.803e-02  3.803e-02
#                               3.253e-03  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  1.830e-03  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -8.476e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.99885)} {np.float64(0.04795)}
# 0.09408813333722299 [ 9.06676443e-01 -1.35525272e-20  4.39533293e-02  4.39533293e-02
#   4.00368170e-03]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.0008709383349196242
#               x: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  1.413e-03
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               1.413e-03  0.000e+00  0.000e+00]
#                  marginals: [ 2.012e+00  6.035e+00  5.020e+00  3.380e-01
#                               0.000e+00  1.509e+00  1.509e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 9.067e-01  0.000e+00  4.395e-02  4.395e-02
#                               4.004e-03  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  1.413e-03  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -8.075e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-0.99973)} {np.float64(0.02339)}
# 0.08384607746620844 [0.89229411 0.         0.05010505 0.05010505 0.00642488]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.0006609376687978108
#               x: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  1.071e-03
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               1.071e-03  0.000e+00  0.000e+00]
#                  marginals: [ 1.902e+00  5.706e+00  4.856e+00  2.833e-01
#                               0.000e+00  1.426e+00  1.426e+00]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 8.923e-01  0.000e+00  5.011e-02  5.011e-02
#                               6.425e-03  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  1.071e-03  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -7.727e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# {np.float64(-1.0)} {np.float64(0.0)}
# 0.07548098069415782 [0.88657939 0.         0.05661074 0.05661074 0.        ]
#         message: Optimization terminated successfully. (HiGHS Status 7: Optimal)
#         success: True
#          status: 0
#             fun: -0.0001327595865787929
#               x: [ 1.991e-04  0.000e+00  0.000e+00 -0.000e+00  0.000e+00
#                    0.000e+00  0.000e+00]
#             nit: 0
#           lower:  residual: [ 1.991e-04  0.000e+00  0.000e+00 -0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [ 0.000e+00  1.334e+00  1.334e+00  0.000e+00
#                              -5.551e-17  3.335e-01  3.335e-01]
#           upper:  residual: [       inf        inf        inf        inf
#                                     inf        inf        inf]
#                  marginals: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00]
#           eqlin:  residual: []
#                  marginals: []
#         ineqlin:  residual: [ 8.866e-01  0.000e+00  5.661e-02  5.661e-02
#                               0.000e+00  1.991e-04  0.000e+00  0.000e+00
#                               0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#                  marginals: [-0.000e+00 -2.001e+00 -0.000e+00 -0.000e+00
#                              -2.668e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                              -0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00]
#  mip_node_count: 0
#  mip_dual_bound: 0.0
#         mip_gap: 0.0
# Updated data saved to updated_hamiltonian_results_j2_j3_T_02.csv
